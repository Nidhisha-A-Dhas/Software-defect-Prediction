# %%
import google.generativeai as genai

# %%
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
genai.configure(api_key=GEMINI_API_KEY)

model = genai.GenerativeModel("gemini-2.5-flash")

# %%
sample = 0

prediction = xgb_model.predict(X_test.iloc[[sample]])[0]

prediction_label = (
    "Defective"
    if prediction == 1
    else "Non-defective"
)

print(prediction_label)
# Out:
# Non-defective

# %%
prompt = f"""
You are a Software Quality Engineer.

A machine learning model predicted that a software module is:

Prediction: {prediction_label}

The five most influential software metrics are:

{top5.to_string(index=False)}

Explain:

1. Why the model predicted this result.
2. What each important software metric means.
3. Whether the developer should be concerned.
4. If the module is defective, suggest practical improvements.

Do not mention SHAP values directly.

Write in simple English.
Limit the response to about 150 words.
"""

# %%
response = model.generate_content(prompt)

print(response.text)
# Out:
# The model predicts this module is non-defective because its specific characteristics, especially the lines of code (loc), difficulty (d), and cyclomatic complexity (v), collectively steer the prediction towards a healthy outcome.
#
# Here's what each metric means:
# *   **loc**: Lines of code, indicating the module's size.
# *   **d**: Halstead's Difficulty, measuring how hard the code might be to understand or develop.
# *   **v**: Cyclomatic Complexity, quantifying the number of independent paths through the code, a key indicator of complexity.
# *   **total_Opnd**: Total operands, which counts variables and constants.
# *   **total_Op**: Total operators, which counts operations like arithmetic or logical statements.
#
# While the prediction is good, the developer should be concerned about the extremely high cyclomatic complexity (`v` at 610.50). This value often signals potential problems like hard-to-test or brittle code, even if not defective yet.
#
# ...
